# %%
import numpy as np
import pandas as pd

from django.conf import settings
from django.db import connections

import os
os.environ["DJANGO_ALLOW_ASYNC_UNSAFE"] = "true"

# %%
p=pd.read_excel(r'd:\a\djellifique\media\missgel\2022\03\31\09_gellifique_20220330-bc.xlsx',header=13,index_col=0,usecols='A:J',nrows=28)
p
# Out:
#                      products Number  color  packing  Order Qty (pc)  \
# No.
# 1             3683 Gel Polish    544    NaN  15ml/PC              60
# 2             3683 Gel Polish    591    NaN  15ml/PC              60
# 3       New base coat - 3839K  CLEAR  CLEAR  15ml/PC              60
# 4             TOP COAT - 3109  CLEAR  CLEAR  15ml/PC             100
# 5             Top Coat - 3130  CLEAR  CLEAR  15ml/PC             100
# 6    3833-XBY SOAK OFF BASE    CLEAR  CLEAR  15ml/PC              60
# 7    3837-TRJF SOAK OFF BASE      12    NaN  15ml/PC              60
# 8    3837-TRJF SOAK OFF BASE      37    NaN  15ml/PC              60
# 9       3683-HSQC gel polish     268    NaN  15ml/PC              60
# 10      3683-HSQC gel polish     227    NaN  15ml/PC              60
# 11      3683-HSQC gel polish     170    NaN  15ml/PC              60
# 12      3683-HSQC gel polish     262    NaN  15ml/PC              60
# 13      3683-HSQC gel polish     244    NaN  15ml/PC              60
# 14      3683-HSQC gel polish     105    NaN  15ml/PC              60
# 15      3683-HSQC gel polish      17    NaN  15ml/PC              60
# 16    3120-KD MILKY TOP COAT       1    NaN   8ml/PC             125
# 17        3120G-SJFC TOP COAT      2    NaN   8ml/PC             125
# 18        3120G-HYFC TOP COAT      2    NaN   8ml/PC             125
# 19        3120G-HYFC TOP COAT      3    NaN   8ml/PC             125
# 20        3120G-BJHY TOP COAT      1    NaN   8ml/PC             125
# 21        3120G-SJFC TOP COAT     12    NaN   8ml/PC             125
# 22         1278C builder gel       2    NaN   50G/PC              60
# 23         1278C builder gel       6    NaN   50G/PC              60
# 24         1278C builder gel      11    NaN   50G/PC              60
# 25         1278C builder gel      13    NaN   50G/PC              60
# 26         1278C builder gel      40    NaN   50G/PC              60
# 27         1278C builder gel      67    NaN   50G/PC              60
# 28         1278C builder gel      74    NaN   50G/PC              60
#
#      Unit price\n（RMB)           Total value          (RMB)        Barcode  \
# No.
# 1                          10.0                       600.0  5060726308199
# 2                          10.0                       600.0  5060726306119
# 3                          10.0                       600.0  5060726300841
# 4                          10.0                      1000.0  5060726308755
# 5                          10.0                      1000.0  5060726308762
# 6                          10.0                       600.0  5060726308984
# 7                          10.0                       600.0  5060726308991
# 8                          10.0                       600.0  5060726309004
# 9                          10.0                       600.0  5060726309011
# 10                         10.0                       600.0  5060726309028
# 11                         10.0                       600.0  5060726309035
# 12                         10.0                       600.0  5060726309042
# 13                         10.0                       600.0  5060726309059
# 14                         10.0                       600.0  5060726309066
# 15                         10.0                       600.0  5060726309073
# 16                          6.5                       812.5  5060726309080
# 17                          6.5                       812.5  5060726309097
# 18                          6.5                       812.5  5060726309103
# 19                          6.5                       812.5  5060726309110
# 20                          6.5                       812.5  5060726309127
# 21                          6.5                       812.5  5060726309134
# 22                         16.5                       990.0  5060726309141
# 23                         16.5                       990.0  5060726309158
# 24                         16.5                       990.0  5060726309165
# 25                         16.5                       990.0  5060726309172
# 26                         16.5                       990.0  5060726309189
# 27                         16.5                       990.0  5060726309196
# 28                         16.5                       990.0  5060726309202
#
#                     Customized Names
# No.
# 1                        CHERRY TART
# 2                          CARNATION
# 3             MICROCRYSTAL BASE COAT
# 4              MICROCRYSTAL TOP COAT
# 5       MICROCRYSTAL ARMOUR TOP COAT
# 6      APEX GEL - STRENGTHEN - CLEAR
# 7    APEX GEL - STRENGTHEN - LE CHIC
# 8    APEX GEL - STRENGTHEN - BONJOUR
# 9                           MALDIVES
# 10                            CACTUS
# 11                           MAGENTA
# 12                         BUTTERCUP
# 13                            CERISE
# 14                            SAILOR
# 15                            MAUVE
# 16                 MILKYWAY TOP COAT
# 17                 CONFETTI TOP COAT
# 18                   COSMIC TOP COAT
# 19               DISCO DIVA TOP COAT
# 20                  UNICORN TOP COAT
# 21               GOLD FLAKE TOP COAT
# 22                      MILK THISTLE
# 23                             BLUSH
# 24                            CHEEKY
# 25                             CREMA
# 26                         BABY PINK
# 27                      MINK SHIMMER
# 28                          LUSTROUS

# %%
p['products']=p['products'].str.upper()
p['packing']=p['packing'].str.replace('/PC','').str.lower()
p.rename(str.lower, axis='columns',inplace=True)
p.rename(str.strip , axis='columns',inplace=True)
p.rename({'unit price\n（rmb)':'price'},axis='columns',inplace=True)
p.rename({'order qty (pc)':'qnt'},axis='columns',inplace=True)
p['customized names']=p['customized names'].str.upper()
p.drop(columns=['color'],inplace=True)
p
# Out:
#                      products number packing  qnt  price  \
# No.
# 1             3683 GEL POLISH    544    15ml   60   10.0
# 2             3683 GEL POLISH    591    15ml   60   10.0
# 3       NEW BASE COAT - 3839K  CLEAR    15ml   60   10.0
# 4             TOP COAT - 3109  CLEAR    15ml  100   10.0
# 5             TOP COAT - 3130  CLEAR    15ml  100   10.0
# 6    3833-XBY SOAK OFF BASE    CLEAR    15ml   60   10.0
# 7    3837-TRJF SOAK OFF BASE      12    15ml   60   10.0
# 8    3837-TRJF SOAK OFF BASE      37    15ml   60   10.0
# 9       3683-HSQC GEL POLISH     268    15ml   60   10.0
# 10      3683-HSQC GEL POLISH     227    15ml   60   10.0
# 11      3683-HSQC GEL POLISH     170    15ml   60   10.0
# 12      3683-HSQC GEL POLISH     262    15ml   60   10.0
# 13      3683-HSQC GEL POLISH     244    15ml   60   10.0
# 14      3683-HSQC GEL POLISH     105    15ml   60   10.0
# 15      3683-HSQC GEL POLISH      17    15ml   60   10.0
# 16    3120-KD MILKY TOP COAT       1     8ml  125    6.5
# 17        3120G-SJFC TOP COAT      2     8ml  125    6.5
# 18        3120G-HYFC TOP COAT      2     8ml  125    6.5
# 19        3120G-HYFC TOP COAT      3     8ml  125    6.5
# 20        3120G-BJHY TOP COAT      1     8ml  125    6.5
# 21        3120G-SJFC TOP COAT     12     8ml  125    6.5
# 22         1278C BUILDER GEL       2     50g   60   16.5
# 23         1278C BUILDER GEL       6     50g   60   16.5
# 24         1278C BUILDER GEL      11     50g   60   16.5
# 25         1278C BUILDER GEL      13     50g   60   16.5
# 26         1278C BUILDER GEL      40     50g   60   16.5
# 27         1278C BUILDER GEL      67     50g   60   16.5
# 28         1278C BUILDER GEL      74     50g   60   16.5
#
#      total value          (rmb)        barcode  \
# No.
# 1                         600.0  5060726308199
# 2                         600.0  5060726306119
# 3                         600.0  5060726300841
# 4                        1000.0  5060726308755
# 5                        1000.0  5060726308762
# 6                         600.0  5060726308984
# 7                         600.0  5060726308991
# 8                         600.0  5060726309004
# 9                         600.0  5060726309011
# 10                        600.0  5060726309028
# 11                        600.0  5060726309035
# 12                        600.0  5060726309042
# 13                        600.0  5060726309059
# 14                        600.0  5060726309066
# 15                        600.0  5060726309073
# 16                        812.5  5060726309080
# 17                        812.5  5060726309097
# 18                        812.5  5060726309103
# 19                        812.5  5060726309110
# 20                        812.5  5060726309127
# 21                        812.5  5060726309134
# 22                        990.0  5060726309141
# 23                        990.0  5060726309158
# 24                        990.0  5060726309165
# 25                        990.0  5060726309172
# 26                        990.0  5060726309189
# 27                        990.0  5060726309196
# 28                        990.0  5060726309202
#
#                     customized names
# No.
# 1                        CHERRY TART
# 2                          CARNATION
# 3             MICROCRYSTAL BASE COAT
# 4              MICROCRYSTAL TOP COAT
# 5       MICROCRYSTAL ARMOUR TOP COAT
# 6      APEX GEL - STRENGTHEN - CLEAR
# 7    APEX GEL - STRENGTHEN - LE CHIC
# 8    APEX GEL - STRENGTHEN - BONJOUR
# 9                           MALDIVES
# 10                            CACTUS
# 11                           MAGENTA
# 12                         BUTTERCUP
# 13                            CERISE
# 14                            SAILOR
# 15                            MAUVE
# 16                 MILKYWAY TOP COAT
# 17                 CONFETTI TOP COAT
# 18                   COSMIC TOP COAT
# 19               DISCO DIVA TOP COAT
# 20                  UNICORN TOP COAT
# 21               GOLD FLAKE TOP COAT
# 22                      MILK THISTLE
# 23                             BLUSH
# 24                            CHEEKY
# 25                             CREMA
# 26                         BABY PINK
# 27                      MINK SHIMMER
# 28                          LUSTROUS

# %%
for c in p.iterrows():
    print(c[1]['products'],c[1]['number'],c[1]['packing'],c[1]['price'],c[1]['customized names'])
# Out:
# 3683 GEL POLISH 544 15ml 10.0 CHERRY TART
# 3683 GEL POLISH 591 15ml 10.0 CARNATION
# NEW BASE COAT - 3839K CLEAR 15ml 10.0 MICROCRYSTAL BASE COAT
# TOP COAT - 3109 CLEAR 15ml 10.0 MICROCRYSTAL TOP COAT
# TOP COAT - 3130 CLEAR 15ml 10.0 MICROCRYSTAL ARMOUR TOP COAT
# 3833-XBY SOAK OFF BASE   CLEAR 15ml 10.0 APEX GEL - STRENGTHEN - CLEAR
# 3837-TRJF SOAK OFF BASE  12 15ml 10.0 APEX GEL - STRENGTHEN - LE CHIC
# 3837-TRJF SOAK OFF BASE  37 15ml 10.0 APEX GEL - STRENGTHEN - BONJOUR
# 3683-HSQC GEL POLISH  268 15ml 10.0 MALDIVES
# 3683-HSQC GEL POLISH  227 15ml 10.0 CACTUS
# 3683-HSQC GEL POLISH  170 15ml 10.0 MAGENTA
# 3683-HSQC GEL POLISH  262 15ml 10.0 BUTTERCUP
# 3683-HSQC GEL POLISH  244 15ml 10.0 CERISE
# 3683-HSQC GEL POLISH  105 15ml 10.0 SAILOR
# 3683-HSQC GEL POLISH  17 15ml 10.0 MAUVE
# 3120-KD MILKY TOP COAT  1 8ml 6.5 MILKYWAY TOP COAT
# 3120G-SJFC TOP COAT 2 8ml 6.5 CONFETTI TOP COAT
# 3120G-HYFC TOP COAT 2 8ml 6.5 COSMIC TOP COAT
# 3120G-HYFC TOP COAT 3 8ml 6.5 DISCO DIVA TOP COAT
# 3120G-BJHY TOP COAT 1 8ml 6.5 UNICORN TOP COAT
# 3120G-SJFC TOP COAT 12 8ml 6.5 GOLD FLAKE TOP COAT
# 1278C BUILDER GEL  2 50g 16.5 MILK THISTLE
# 1278C BUILDER GEL  6 50g 16.5 BLUSH
# 1278C BUILDER GEL  11 50g 16.5 CHEEKY
# 1278C BUILDER GEL  13 50g 16.5 CREMA
# 1278C BUILDER GEL  40 50g 16.5 BABY PINK
# 1278C BUILDER GEL  67 50g 16.5 MINK SHIMMER
# 1278C BUILDER GEL  74 50g 16.5 LUSTROUS

# %%
sql = """
insert ignore into gellifihouse_missgelproducts (name,color_number,packing,price,gellifique_name,gellifique_ean13) values (%s,%s,%s,%s,%s,%s)
"""

# %%
sql = """
insert ignore into gellifihouse_missgelorderdetail (name,color_number,packing,price,gellifique_name,gellifique_ean13,quantity,total_cost,order_id) 
    values (%s,%s,%s,%s,%s,%s,%s,%s,%s)
"""

# %%
with connections['default'].cursor() as cursor:
    for c in p.iterrows():
        print(c[1]['products'],c[1]['number'],c[1]['packing'],c[1]['price'],c[1]['customized names'])
        cursor.execute(sql,(c[1]['products'],c[1]['number'],c[1]['packing'],c[1]['price'],c[1]['customized names'],c[1]['barcode']))

# %%
with connections['default'].cursor() as cursor:
    for c in p.iterrows():
        print(c[1]['products'],c[1]['number'],c[1]['packing'],c[1]['price'],c[1]['customized names'])
        cursor.execute(sql,(c[1]['products'],c[1]['number'],c[1]['packing'],c[1]['price'],c[1]['customized names'],c[1]['barcode'],c[1]['qnt'],c[1]['total'],4))
# Out:
# GEL POLISH 3683 H048 15ml 11.0 AMETHYST
# NO WIPE TOP COAT 3130 CLEAR 15ml 8.0 ARMOUR TOP COAT
# GEL POLISH 3683 CLEAR 15ml 10.0 ASPHALT
# GEL POLISH 3683 CLEAR 15ml 10.0 AUBERGINE
# GEL POLISH 3683 CLEAR 15ml 10.0 BISCOTTI
# GEL POLISH 3533A-1708-HPLL CLEAR 15ml 10.0 BLACK GLASS
# GEL POLISH 3683 CLEAR 15ml 10.0 BLACK PANTHER
# GEL POLISH 3683 CLEAR 15ml 10.0 BLACKBERRY
# GEL POLISH 3683 CLEAR 8ml 6.5 BLACKBERRY
# GEL POLISH 3683 CLEAR 15ml 10.0 BLACKCURRANT
# GEL POLISH 3683 CLEAR 15ml 10.0 BLANCO
# BLOOMING GEL 2057 CLEAR 15ml 8.0 BLOOMING GEL
# GEL POLISH 3683 CLEAR 15ml 10.0 BOLT
# GEL POLISH 3683 CLEAR 15ml 10.0 BOUQUET
# GEL POLISH 3683 CLEAR 8ml 6.5 BOUQUET
# GEL POLISH 3683 CLEAR 15ml 10.0 BRIDE TO BE
# GEL POLISH 3683 CLEAR 15ml 10.0 BRUSHED SUEDE
# GEL POLISH 3683 CLEAR 15ml 10.0 BURLESQUE
# GEL POLISH 3683 CLEAR 15ml 10.0 CANDY APPLE
# GEL POLISH 3683 CLEAR 15ml 10.0 CARBON
# GEL POLISH 3683 CLEAR 15ml 10.0 CHARCOAL
# GEL POLISH 3683 CLEAR 15ml 10.0 CHERRY TART
# GEL POLISH 3683 CLEAR 15ml 10.0 CHESTNUT
# GEL POLISH 3683 CLEAR 15ml 10.0 CLOUD 09
# GEL POLISH 3683 CLEAR 15ml 10.0 COBALT
# GEL POLISH 3683 CLEAR 15ml 10.0 COCOA NIB
# GEL POLISH 3683 CLEAR 8ml 6.5 COCOA NIB
# GEL POLISH 3683 CLEAR 15ml 10.0 COLA
# GEL POLISH 3683 CLEAR 15ml 10.0 COPACABANA
# GEL POLISH 3683 G174 15ml 10.0 COPPER EMBERS
# GEL POLISH 3683 G174 8ml 6.5 COPPER EMBERS
# GEL POLISH 3683 G318 15ml 10.0 COPPER SPARK
# GEL POLISH 3683 CLEAR 15ml 10.0 CORDELIA
# GEL POLISH 3683 CLEAR 8ml 6.5 CORDELIA
# BUILDER GEL 3910-ARP CLEAR 50g 16.5 CRYSTAL
# GEL POLISH 3683 CLEAR 15ml 10.0 DAMASK ROSE
# GEL POLISH 3683 CLEAR 8ml 6.5 DAMASK ROSE
# GEL POLISH 3683 CLEAR 15ml 10.0 DAMSON
# GEL POLISH 3683 CLEAR 15ml 10.0 DAYDREAM
# GEL POLISH 3683 G398 15ml 10.0 DIANA
# GEL POLISH 3683 G398 8ml 6.5 DIANA
# GEL POLISH 3683 CLEAR 15ml 10.0 DUSKY ROSE
# APEX GEL 3608 CLEAR 15ml 10.0 DUSTY ROSE
# GEL POLISH 3683 CLEAR 15ml 10.0 ESPRESSO
# GEL POLISH 3683 CLEAR 15ml 10.0 FIERY BROWN
# GEL POLISH 3655-SDKH CLEAR 15ml 10.0 FIREWORK FUCHSIA
# GEL POLISH 3683 CLEAR 15ml 10.0 FORGET ME NOT
# BUILDER GEL 1280C CLEAR 50g 16.5 ARCTIC FROST
# GEL POLISH 3683 CLEAR 15ml 10.0 GEISHA
# GEL POLISH 3683 CLEAR 15ml 10.0 GRAPE
# GEL POLISH 3683 G407 15ml 10.0 HAZELNUT
# GEL POLISH 3655-SDKH CLEAR 15ml 10.0 HEART OF THE OCEAN
# GEL POLISH 2909 CLEAR 15ml 10.0 HONEYDEW CRUSH
# GEL POLISH 3683 CLEAR 15ml 10.0 IRISH CREAM
# GEL POLISH 3683 CLEAR 8ml 6.5 IRISH CREAM
# GEL POLISH 3683 G393 15ml 10.0 JELLY BEAN
# GEL POLISH 3683 G393 8ml 6.5 JELLY BEAN
# GEL POLISH 2909 CLEAR 15ml 10.0 LEMON SORBET
# GEL POLISH 3683 CLEAR 15ml 10.0 LONDON CITY
# GEL POLISH 3683 CLEAR 15ml 10.0 MANHATTAN
# GEL POLISH 3683 CLEAR 15ml 10.0 MEADOWSWEET
# GEL POLISH 3683 CLEAR 8ml 6.5 MEADOWSWEET
# BASE COAT 3812 CLEAR 15ml 8.0 MICROCRYSTAL BASE COAT
# SOAK OFF TOP COAT 3109 CLEAR 15ml 8.0 MICROCRYSTAL TOP COAT
# GEL POLISH 3683 CLEAR 15ml 10.0 MILE HIGH
# BUILDER GEL 1280C CLEAR 50g 16.5 DARLING
# BUILDER GEL 1280C CLEAR 50g 16.5 SMITTEN
# GEL POLISH 3683 G264 15ml 10.0 NIGHTSHADE
# GEL POLISH 3683 CLEAR 15ml 10.0 NIMBUS
# GEL POLISH 3683 G088 15ml 10.0 NORTH STAR
# APEX GEL 3608 CLEAR 15ml 10.0 HAWAIIAN MACADAMIA
# GEL POLISH 3683 CLEAR 15ml 10.0 OCHRE
# GEL POLISH 3683 CLEAR 8ml 6.5 OCHRE
# APEX GEL 3608 CLEAR 15ml 10.0 PETAL PINK
# GEL POLISH 3683 CLEAR 15ml 10.0 PINK CARNATION
# GEL POLISH 3683 CLEAR 8ml 6.5 PINK CARNATION
# GEL POLISH 3683 H055 15ml 11.0 PLUM JAM
# GEL POLISH 3683 H055 8ml 7.5 PLUM JAM
# GEL POLISH 3683 G224 15ml 10.0 PLUM PUDDING
# GEL POLISH 3683 CLEAR 15ml 10.0 PLUSH MINK
# GEL POLISH 3683 CLEAR 8ml 6.5 PLUSH MINK
# GEL POLISH 3683 G379 15ml 10.0 PRINCESS
# GEL POLISH 3683 G379 8ml 6.5 PRINCESS
# GEL POLISH 3683 CLEAR 15ml 10.0 PUMPKIN SPICE
# GEL POLISH 3683 CLEAR 8ml 6.5 PUMPKIN SPICE
# GEL POLISH 3683 CLEAR 15ml 10.0 ROMANCE
# GEL POLISH 3683 CLEAR 15ml 10.0 ROSE GARDEN
# GEL POLISH 3683 CLEAR 8ml 6.5 ROSE GARDEN
# BUILDER GEL 1280C CLEAR 50g 16.5 AMOUR
# GEL POLISH 3683 CLEAR 15ml 10.0 ROSEBUD
# RUBBER BASE COAT 3827 CLEAR 15ml 8.0 RUBBER BASE COAT MEDIUM
# RUBBER TOP COAT 3102-11 CLEAR 15ml 8.0 RUBBER TOP COAT
# GEL POLISH 3683 G239 15ml 10.0 SAPPHIRE
# GEL POLISH 3655-SDKH CLEAR 15ml 10.0 SHOOTING STAR
# GEL POLISH 3683 G045 15ml 10.0 SILVER RAIN
#
# GEL POLISH 3683 CLEAR 15ml 10.0 SLATE
# GEL POLISH 3683 G284 15ml 10.0 STARRY SKY
# GEL POLISH 3683 CLEAR 15ml 10.0 STORM
# GEL POLISH 3683 CLEAR 15ml 10.0 STORMY PURPLE
# GEL POLISH 3683 G146 15ml 10.0 SUNBORN
# GEL POLISH 3683 G397 15ml 10.0 SWEETHEART
# GEL POLISH 3683 G408 15ml 10.0 TIRAMISU
# GEL POLISH 3683 CLEAR 15ml 10.0 TOFFEE NUT
# GEL POLISH 3533A-1708-HPLL CLEAR 15ml 10.0 TORTOISE SHELL
# TRANSFER GEL 2058 CLEAR 15ml 8.0 TRANSFER GEL
# GEL POLISH 3683 CLEAR 15ml 10.0 TRUFFLE
# GEL POLISH 3683 CLEAR 15ml 10.0 TURKISH DELIGHT
# GEL POLISH 3683 CLEAR 15ml 10.0 ULTRAMARINE
# GEL POLISH 3683 CLEAR 8ml 6.5 ULTRAMARINE
# GEL POLISH 3683 CLEAR 15ml 10.0 URBAN CHIC
# MATTE TOP COAT 3118 CLEAR 15ml 8.0 VELVET MATTE TOP COAT
# GEL POLISH 3683 G509 15ml 10.0 VERY BERRY
# PAINTING GEL 3848 001 15g 8.0 WHITE
# PAINTING GEL 3848 288 15g 8.0 BLACK
# SOAK OFF GEL POLISH 2020-MG CLEAR 8ml 6.5  LAVENDER MERINGUE
# SOAK OFF GEL POLISH 2020-MG CLEAR 8ml 6.5 MINT TART
# SOAK OFF GEL POLISH 2020-MG CLEAR 8ml 6.5 STRAWBERRY SHORTCAKE
# SOAK OFF GEL POLISH 2020-MG CLEAR 8ml 6.5 LEMON POSSET
# SOAK OFF GEL POLISH 2020-MG CLEAR 8ml 6.5 BLUEBERRY PIE
# SOAK OFF GEL POLISH 2020-MG CLEAR 8ml 6.5  PEACH COBBLER
# SOAK OFF GEL POLISH 2020-MG CLEAR 15ml 10.0  LAVENDER MERINGUE
# SOAK OFF GEL POLISH 2020-MG CLEAR 15ml 10.0 MINT TART
# SOAK OFF GEL POLISH 2020-MG CLEAR 15ml 10.0 STRAWBERRY SHORTCAKE
# SOAK OFF GEL POLISH 2020-MG CLEAR 15ml 10.0 LEMON POSSET
# SOAK OFF GEL POLISH 2020-MG CLEAR 15ml 10.0 BLUEBERRY PIE
# SOAK OFF GEL POLISH 2020-MG CLEAR 15ml 10.0  PEACH COBBLER

# %%
p=pd.read_excel(r'd:\a\djellifique\media\missgel\2022\03\31\09_gellifique20211009_with_BARCODES_excel.xlsx',header=13,index_col=0,usecols='A:J',nrows=89)
p
# Out:
#                    products           Number color  packing  Order Qty (pc)  \
# No.
# 1           3683 Gel Polish              939   NaN  15ml/PC              60
# 2    3703G-FGSH Gel Polish                14   NaN  15ml/PC              60
# 3           3683 Gel Polish              776   NaN  15ml/PC             100
# 4           3683 Gel Polish              775   NaN  15ml/PC             120
# 5           3683 Gel Polish              968   NaN  15ml/PC              60
# ..                      ...              ...   ...      ...             ...
# 85            MS-QT-P32-CKG              NaN   NaN      NaN              60
# 86            MS-QT-P07-CKG              NaN   NaN      NaN              60
# 87           MS-TN-SL01-CKG              NaN   NaN      NaN              60
# 88               PS 200 - 6  12 design*10pcs   NaN      NaN              40
# 89               PS 200 - 7  12 design*10pcs   NaN      NaN              40
#
#      Unit price\n（RMB)           Total value          (RMB)        Barcode  \
# No.
# 1                            10                         600  5060726308007
# 2                            15                         900  5060726308014
# 3                            10                        1000  5060726308021
# 4                            10                        1200  5060726308038
# 5                            10                         600  5060726308045
# ..                          ...                         ...            ...
# 85                           29                        1740  5060726308939
# 86                           24                        1440  5060726308946
# 87                           24                        1440  5060726308953
# 88                            8                         320  5060726308960
# 89                            8                         320  5060726308977
#
#                  Customized Names
# No.
# 1                      ALMOND OIL
# 2     BLACK DIAMOND / Platinum 12
# 3                  BLACK PANTHER
# 4                         BLANCO
# 5                   CAFE AU LATTE
# ..                            ...
# 85   TIPS - SHORT OVAL PRE ETCHED
# 86                TIPS - STILLTTO
# 87                TIPS - PEDICURE
# 88                     PS 200 - 6
# 89                     PS 200 - 7
#
# [89 rows x 9 columns]

# %%
p['products']=p['products'].str.upper()
p['packing']=p['packing'].str.replace('/PC','').str.lower()
p.rename(str.lower, axis='columns',inplace=True)
p.rename(str.strip , axis='columns',inplace=True)
p.rename({'unit price\n（rmb)':'price'},axis='columns',inplace=True)
p.rename({'order qty (pc)':'qnt'},axis='columns',inplace=True)
p.rename({'total value          (rmb)':'total'},axis='columns',inplace=True)
p.loc[p['number'].isnull(),'number']='CLEAR'
p.loc[p['packing'].isnull(),'packing']='-'
p.loc[p['customized names'].isnull(),'customized names']='?'
p['customized names']=p['customized names'].str.upper()
#p.drop(columns=['color'],inplace=True)
p
# Out:
#                    products           number packing  qnt  price  total  \
# No.
# 1           3683 GEL POLISH              939    15ml   60     10    600
# 2    3703G-FGSH GEL POLISH                14    15ml   60     15    900
# 3           3683 GEL POLISH              776    15ml  100     10   1000
# 4           3683 GEL POLISH              775    15ml  120     10   1200
# 5           3683 GEL POLISH              968    15ml   60     10    600
# ..                      ...              ...     ...  ...    ...    ...
# 85            MS-QT-P32-CKG            CLEAR       -   60     29   1740
# 86            MS-QT-P07-CKG            CLEAR       -   60     24   1440
# 87           MS-TN-SL01-CKG            CLEAR       -   60     24   1440
# 88               PS 200 - 6  12 design*10pcs       -   40      8    320
# 89               PS 200 - 7  12 design*10pcs       -   40      8    320
#
#            barcode              customized names
# No.
# 1    5060726308007                    ALMOND OIL
# 2    5060726308014   BLACK DIAMOND / PLATINUM 12
# 3    5060726308021                BLACK PANTHER
# 4    5060726308038                       BLANCO
# 5    5060726308045                 CAFE AU LATTE
# ..             ...                           ...
# 85   5060726308939  TIPS - SHORT OVAL PRE ETCHED
# 86   5060726308946               TIPS - STILLTTO
# 87   5060726308953               TIPS - PEDICURE
# 88   5060726308960                    PS 200 - 6
# 89   5060726308977                    PS 200 - 7
#
# [89 rows x 8 columns]

# %%
p.columns
# Out:
# Index(['products', 'number', 'packing', 'qnt', 'price',
#        'total value          (rmb)', 'barcode', 'customized names'],
#       dtype='object')

# %%
p.loc[p['number'].isnull(),'number']='CLEAR'
p.loc[p['packing'].isnull(),'packing']='-'
p.loc[p['customized names'].isnull(),'customized names']='?'

# %%
p=pd.read_excel(r'd:\a\djellifique\media\missgel\2022\04\01\09_gellifique20210630.xlsx',header=13,index_col=0,usecols='A:J',nrows=78)
p
# Out:
#                     products  color  packing  Order Qty (pc)  \
# No.
# 1          Gel Polish - 3683    628  15ml/PC              60
# 2          Gel Polish - 3683    300  15ml/PC              60
# 3          Gel Polish - 3683    829  15ml/PC              60
# 4        Gel Polish - 3683\t    163  15ml/PC              60
# 5            Gel polsih 3683    113  15ml/PC              60
# ..                       ...    ...      ...             ...
# 74           Gel polish 2909   1023   8ml/PC              50
# 75           Top Coat - 3109  CLEAR   8ml/PC              50
# 76   Soak off base coat 3812  CLEAR   8ml/PC              50
# 77           Top Coat - 3130  CLEAR   8ml/PC              50
# 78   Rubber base coat - 3827  CLEAR   8ml/PC              50
#
#      Unit price\n（RMB)           Total value          (RMB)        Barcode  \
# No.
# 1                          10.0                         600  5060726307000
# 2                          10.0                         600  5060726307017
# 3                          10.0                         600  5060726307024
# 4                          10.0                         600  5060726307031
# 5                          10.0                         600  5060726307048
# ..                          ...                         ...            ...
# 74                          6.5                         325  5060726307413
# 75                          6.5                         325  5060726307437
# 76                          6.5                         325  5060726307567
# 77                          6.5                         325  5060726307529
# 78                          6.5                         325  5060726307543
#
#                      Customized Names  Unnamed: 9
# No.
# 1                             ADMIRAL         NaN
# 2                         BLUE HAWAII         NaN
# 3                         BRIDE TO BE         NaN
# 4                       BRUSHED SUEDE         NaN
# 5                           BUBBLEGUM         NaN
# ..                                ...         ...
# 74              STRAWBERRY BLISS 8 ml         NaN
# 75         MICROCRYSTAL TOP COAT 8 ml         NaN
# 76         MICROCRYSTAL BASE COAT 8ml         NaN
# 77   MICROCRYSTAL ARMOUR TOP COAT 8ml         NaN
# 78          RUBBER BASE - MEDIUM 8 ml         NaN
#
# [78 rows x 9 columns]

# %%
p['products']=p['products'].str.upper()
p['packing']=p['packing'].str.replace('/PC','').str.lower()
p.rename(str.lower, axis='columns',inplace=True)
p.rename(str.strip , axis='columns',inplace=True)
p.rename({'unit price\n（rmb)':'price'},axis='columns',inplace=True)
p.rename({'order qty (pc)':'qnt'},axis='columns',inplace=True)
p.rename({'total value          (rmb)':'total'},axis='columns',inplace=True)
p['customized names']=p['customized names'].str.upper()
p['number']=p['color']
p.loc[p['number'].isnull(),'number']='CLEAR'
p.loc[p['packing'].isnull(),'packing']='-'
p
# Out:
#                     products  color packing  qnt  price  total        barcode  \
# No.
# 1          GEL POLISH - 3683    628    15ml   60   10.0    600  5060726307000
# 2          GEL POLISH - 3683    300    15ml   60   10.0    600  5060726307017
# 3          GEL POLISH - 3683    829    15ml   60   10.0    600  5060726307024
# 4        GEL POLISH - 3683\t    163    15ml   60   10.0    600  5060726307031
# 5            GEL POLSIH 3683    113    15ml   60   10.0    600  5060726307048
# ..                       ...    ...     ...  ...    ...    ...            ...
# 74           GEL POLISH 2909   1023     8ml   50    6.5    325  5060726307413
# 75           TOP COAT - 3109  CLEAR     8ml   50    6.5    325  5060726307437
# 76   SOAK OFF BASE COAT 3812  CLEAR     8ml   50    6.5    325  5060726307567
# 77           TOP COAT - 3130  CLEAR     8ml   50    6.5    325  5060726307529
# 78   RUBBER BASE COAT - 3827  CLEAR     8ml   50    6.5    325  5060726307543
#
#                      customized names  unnamed: 9 number
# No.
# 1                             ADMIRAL         NaN    628
# 2                         BLUE HAWAII         NaN    300
# 3                         BRIDE TO BE         NaN    829
# 4                       BRUSHED SUEDE         NaN    163
# 5                           BUBBLEGUM         NaN    113
# ..                                ...         ...    ...
# 74              STRAWBERRY BLISS 8 ML         NaN   1023
# 75         MICROCRYSTAL TOP COAT 8 ML         NaN  CLEAR
# 76         MICROCRYSTAL BASE COAT 8ML         NaN  CLEAR
# 77   MICROCRYSTAL ARMOUR TOP COAT 8ML         NaN  CLEAR
# 78          RUBBER BASE - MEDIUM 8 ML         NaN  CLEAR
#
# [78 rows x 10 columns]

# %%
p=pd.read_excel(r'd:\a\djellifique\media\missgel\2022\04\01\15_gellifique20201230_2_copy.xlsx',header=13,index_col=0,usecols='A:H',nrows=81)
p
# Out:
#              products color packing  Order Qty (pc)  \
# No.
# NaN  Base 3840X - XBY    19   15 GR              60
# NaN  Base 3840X - XBY    17   15 GR              60
# NaN  Base 3840X - XBY    10   15 GR              60
# NaN   3683 Gel Polish   379      15              60
# NaN   3683 Gel Polish   382      15              60
# ..                ...   ...     ...             ...
# NaN     MS-QT-P25-CKG   NaN     pcs              30
# NaN     MS-QT-P32-CKG   NaN     pcs              30
# NaN     MS-QT-P22-CKG   NaN     pcs              30
# NaN     MS-QT-P07-CKG   NaN     pcs              30
# NaN       MS-CB04-CKG   NaN     pcs              30
#
#      Unit price\n（RMB)           Total value          (RMB)  \
# No.
# NaN                        10.0                         600
# NaN                        10.0                         600
# NaN                        10.0                         600
# NaN                        10.0                         600
# NaN                        10.0                         600
# ..                          ...                         ...
# NaN                        24.0                         720
# NaN                        29.0                         870
# NaN                        24.0                         720
# NaN                        24.0                         720
# NaN                        24.0                         720
#
#                     Customized Names
# No.
# NaN  APEX GEL - STRENGTHEN - NATURAL
# NaN  APEX GEL - STRENGTHEN - NUDE 02
# NaN     APEX GEL - STRENGTHEN - PINK
# NaN                    Peach Blossom
# NaN                      APRICOT new
# ..                               ...
# NaN         SHORT ALMOND PRE ETCHED
# NaN                 OVAL PRE ETCHED
# NaN                        BALLERINA
# NaN                         STILLETO
# NaN                      LONG ALMOND
#
# [81 rows x 7 columns]

# %%
p['products']=p['products'].str.upper()
p['packing']=p['packing'].str.replace('/PC','').str.lower()
p['packing']=p['packing'].str.replace('/pc','').str.lower()
p.rename(str.lower, axis='columns',inplace=True)
p.rename(str.strip , axis='columns',inplace=True)
p.rename({'unit price\n（rmb)':'price'},axis='columns',inplace=True)
p.rename({'order qty (pc)':'qnt'},axis='columns',inplace=True)
p.rename({'total value          (rmb)':'total'},axis='columns',inplace=True)
p['customized names']=p['customized names'].str.upper()
p['number']=p['color']
p['products']=p['products'].str.strip()
p['number']=p['number'].str.upper()

#p['packing']=p['packing'].str.replace('gr','ml').str.lower()
p.loc[p['number'].isnull(),'number']='CLEAR'
p.loc[p['packing'].isnull(),'packing']='-'
p.loc[p['customized names'].isnull(),'customized names']='-'
p['barcode']=''
p
# Out:
#                          products  color packing  qnt  price  total  \
# No.
# 1.0               GEL POLISH 3683   H048    15ml   60   11.0  660.0
# 2.0         NO WIPE TOP COAT 3130  clear    15ml   60    8.0  480.0
# 3.0               GEL POLISH 3683    757    15ml   60   10.0  600.0
# 4.0               GEL POLISH 3683    808    15ml   60   10.0  600.0
# 5.0               GEL POLISH 3683     99    15ml   60   10.0  600.0
# ...                           ...    ...     ...  ...    ...    ...
# 8.0   SOAK OFF GEL POLISH 2020-MG      8    15ml   33   10.0  330.0
# 9.0   SOAK OFF GEL POLISH 2020-MG      6    15ml   33   10.0  330.0
# 10.0  SOAK OFF GEL POLISH 2020-MG      7    15ml   33   10.0  330.0
# 11.0  SOAK OFF GEL POLISH 2020-MG      9    15ml   33   10.0  330.0
# 12.0  SOAK OFF GEL POLISH 2020-MG     12    15ml   33   10.0  330.0
#
#           customized names number barcode
# No.
# 1.0               AMETHYST   H048
# 2.0        ARMOUR TOP COAT  CLEAR
# 3.0                ASPHALT  CLEAR
# 4.0              AUBERGINE  CLEAR
# 5.0               BISCOTTI  CLEAR
# ...                    ...    ...     ...
# 8.0              MINT TART  CLEAR
# 9.0   STRAWBERRY SHORTCAKE  CLEAR
# 10.0          LEMON POSSET  CLEAR
# 11.0         BLUEBERRY PIE  CLEAR
# 12.0         PEACH COBBLER  CLEAR
#
# [126 rows x 9 columns]

# %%
p['products']=p['products'].str.strip()
p['number']=p['number'].str.upper()
p.loc[p['number'].isnull(),'number']='CLEAR'
p['number']=p['color']
p
# Out:
#                          products  color packing  qnt  price  \
# No.
# 1.0               GEL POLISH 3683   H048    15ml   60   11.0
# 2.0         NO WIPE TOP COAT 3130  clear    15ml   60    8.0
# 3.0               GEL POLISH 3683    757    15ml   60   10.0
# 4.0               GEL POLISH 3683    808    15ml   60   10.0
# 5.0               GEL POLISH 3683     99    15ml   60   10.0
# ...                           ...    ...     ...  ...    ...
# 8.0   SOAK OFF GEL POLISH 2020-MG      8    15ml   33   10.0
# 9.0   SOAK OFF GEL POLISH 2020-MG      6    15ml   33   10.0
# 10.0  SOAK OFF GEL POLISH 2020-MG      7    15ml   33   10.0
# 11.0  SOAK OFF GEL POLISH 2020-MG      9    15ml   33   10.0
# 12.0  SOAK OFF GEL POLISH 2020-MG     12    15ml   33   10.0
#
#       total value          (rmb)      customized names number barcode
# No.
# 1.0                        660.0              AMETHYST   H048
# 2.0                        480.0       ARMOUR TOP COAT  clear
# 3.0                        600.0               ASPHALT    757
# 4.0                        600.0             AUBERGINE    808
# 5.0                        600.0              BISCOTTI     99
# ...                          ...                   ...    ...     ...
# 8.0                        330.0             MINT TART      8
# 9.0                        330.0  STRAWBERRY SHORTCAKE      6
# 10.0                       330.0          LEMON POSSET      7
# 11.0                       330.0         BLUEBERRY PIE      9
# 12.0                       330.0         PEACH COBBLER     12
#
# [126 rows x 9 columns]

# %%
p['barcode']=''

# %%
p=pd.read_excel(r'd:\a\djellifique\media\missgel\2022\04\01\23_Gellifique20200630combined_invoice.xlsx',header=13,index_col=0,usecols='A:H',nrows=126)
p
# Out:
#                          products  color  packing  Order Qty (pc)  \
# No.
# 1.0               Gel Polish 3683   H048  15ml/pc              60
# 2.0         No wipe top coat 3130  clear  15ml/pc              60
# 3.0               Gel Polish 3683    757  15ml/pc              60
# 4.0               Gel Polish 3683    808  15ml/pc              60
# 5.0               Gel Polish 3683     99  15ml/pc              60
# ...                           ...    ...      ...             ...
# 8.0   soak off gel polish 2020-MG      8  15ml/pc              33
# 9.0   soak off gel polish 2020-MG      6  15ml/pc              33
# 10.0  soak off gel polish 2020-MG      7  15ml/pc              33
# 11.0  soak off gel polish 2020-MG      9  15ml/pc              33
# 12.0  soak off gel polish 2020-MG     12  15ml/pc              33
#
#       Unit price\n（RMB)           Total value          (RMB)  \
# No.
# 1.0                         11.0                       660.0
# 2.0                          8.0                       480.0
# 3.0                         10.0                       600.0
# 4.0                         10.0                       600.0
# 5.0                         10.0                       600.0
# ...                          ...                         ...
# 8.0                         10.0                       330.0
# 9.0                         10.0                       330.0
# 10.0                        10.0                       330.0
# 11.0                        10.0                       330.0
# 12.0                        10.0                       330.0
#
#           Customized Names
# No.
# 1.0               Amethyst
# 2.0        Armour Top Coat
# 3.0                Asphalt
# 4.0              Aubergine
# 5.0               Biscotti
# ...                    ...
# 8.0              mint tart
# 9.0   Strawberry shortcake
# 10.0          lemon posset
# 11.0         blueberry pie
# 12.0         peach cobbler
#
# [126 rows x 7 columns]
